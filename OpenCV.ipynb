# %% [markdown]
# # OpenCV with Python

# %% [markdown]
# Disclaimer
#
# Holy shit, I managed to install OpenCV on mac, just 2 hours of intence googling ang fighting with homebrew

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/Users/dmitrys/Desktop/watch.JPG', cv2.IMREAD_GRAYSCALE)

# %%
#IMREAD_GRAYSCALE = 0
#IMREAD_COLOR = 1
#IMREAD_UNCHANGED = -1

# %%
cv2.imshow('image', img)
cv2.waitKey(0) # pressing enter will close the image
cv2.destroyAllWindows()

# %%
# %matplotlib inline

# %%
plt.imshow(img, cmap="gray", interpolation='bicubic')

# %% [markdown]
# # Video

# %%
cap = cv2.VideoCapture(0)

fourcc = cv2.cv.CV_FOURCC(*'XVID')
out = cv2.VideoWriter('/Users/dmitrys/Desktop/output.avi', fourcc, 20.0, (640, 480))

while True:
    ret, frame = cap.read()
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    out.write(frame)
    cv2.imshow('frame', frame)
    cv2.imshow('gray', gray)
    
    if cv2.waitKey(1) & 0xFF== ord('q'):
        break

        
        
cap.release()
out.release()
cv2.destroyAllWindows()

# %%
cv2.destroyAllWindows()

# %% [markdown]
# # Drawing and writing on images

# %%
img = cv2.imread('/Users/dmitrys/Desktop/watch.JPG', cv2.IMREAD_COLOR)

# %%
cv2.line(img, (0, 0), (150, 150), (0, 255, 0), 15)

cv2.rectangle(img, (15, 25), (200, 150), (0, 0, 255), 5)

cv2.circle(img, (100, 300), 55, (0, 255, 255), -1) # -1 fills the shape in

pts = np.array([[100, 5], [200, 300], [700, 100], [500, 100], [800, 800]], np.int32)
#pts = pts.reshape((-1, 1, 2))

cv2.polylines(img, [pts], True, (255, 255, 0), 5) # True for connection the beginning with the final

font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, 'OpenCV Test!', (0, 130), font, 2, (0, 0, 0), 2)


cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Image Operations

# %%
img = cv2.imread('/Users/dmitrys/Desktop/watch.JPG', cv2.IMREAD_COLOR)

# %%
px = img[55, 55] # we can get colorvalue of the pixel
img[55, 55] = [0, 0, 0] # and modify the value of the pixel

img[100:150, 100:150] = [0, 0, 0] # and even modify areas on the image

# %%
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
